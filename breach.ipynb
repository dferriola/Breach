# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
from mpl_toolkits.basemap import Basemap
plt.style.use('seaborn-talk')
import os

# %%
df=pd.read_csv('breach_report.csv')
print(plt.style.available)
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn-dark-palette']

# %%
df.dropna()
df[:10]
# Out:
#                               Name of Covered Entity State  \
# 0                         Brooke Army Medical Center    TX
# 1          Mid America Kidney Stone Association, LLC    MO
# 2    Alaska Department of Health and Social Services    AK
# 3  Health Services for Children with Special Need...    DC
# 4                                  Mark D. Lurie, MD    CA
# 5                           L. Douglas Carlson, M.D.    CA
# 6                                 David I. Cohen, MD    CA
# 7                            Michele Del Vicario, MD    CA
# 8                                Joseph F. Lopez, MD    CA
# 9               City of Hope National Medical Center    CA
#
#    Covered Entity Type  Individuals Affected Breach Submission Date  \
# 0  Healthcare Provider                1000.0               10/21/09
# 1  Healthcare Provider                1000.0               10/28/09
# 2  Healthcare Provider                 501.0               10/30/09
# ...

# %%
loc=df['Location of Breached Information'].value_counts()

# %%
loc=loc[:10].plot(kind='barh')
loc.invert_yaxis()
pylab.title('Location of Breached Information')

# %%
state=df['State'].value_counts()

# %%
state[:10].plot(kind='bar')
pylab.title('State Freq of Data Breaches')

# %%
year=df['Year'].value_counts()

# %%
year[:10].plot(kind='bar')

# %%
df.describe()
# Out:
#        Individuals Affected          Day        Month         Year
# count          1.646000e+03  1658.000000  1658.000000  1658.000000
# mean           1.024573e+05    15.951146     6.413752  2013.174910
# std            1.997579e+06     8.706266     3.351304     1.978349
# min            5.000000e+02     1.000000     1.000000  2009.000000
# 25%            9.982500e+02     9.000000     4.000000  2012.000000
# 50%            2.300000e+03    15.000000     6.000000  2013.000000
# 75%            7.599750e+03    23.750000     9.000000  2015.000000
# max            7.880000e+07    31.000000    12.000000  2016.000000

# %%
df.dtypes
# Out:
# Name of Covered Entity               object
# State                                object
# Covered Entity Type                  object
# Individuals Affected                float64
# Breach Submission Date               object
# Type of Breach                       object
# Location of Breached Information     object
# Business Associate Present           object
# Web Description                      object
# Day                                   int64
# Month                                 int64
# Year                                  int64
# dtype: object

# %%
who=df[['Name of Covered Entity', 'Individuals Affected']]
state=df[['State', 'Individuals Affected']]

# %%
who.head()
# Out:
#    State  Individuals Affected
# 0     TX                1000.0
# 1     MO                1000.0
# 2     AK                 501.0
# 3     DC                3800.0
# 4     CA                5166.0
# 5     CA                5257.0
# 6     CA                 857.0
# 7     CA                6145.0
# 8     CA                 952.0
# 9     CA                5900.0
# 10    PA                 943.0
# 11    TN                6400.0
# 12    VA               83000.0
# 13    CA                 596.0
# 14    NC                2000.0
# 15    MI                 646.0
# 16    MI               10000.0
# 17    CA                 610.0
# 18    MA                1860.0
# 19    DC                3400.0

# %%
who_group=who.groupby('Individuals Affected')

# %%
locb=df['Type of Breach'].value_counts()
l=locb[:10].plot(kind='barh')
l.invert_yaxis()
pylab.title('Type of Breach')

# %%
set_keywords = set()
for liste_keywords in df_initial['Web Description'].str.split('|').values:
    if isinstance(liste_keywords, float): continue
    set keywords = set_keywords.union(liste_keywords)
set_keywords.remove('')
# Out:
#   File "<ipython-input-75-2459346e3e14>", line 4
#     set keywords = set_keywords.union(liste_keywords)
#                ^
# SyntaxError: invalid syntax

# %%
hprov=df.Covered Entity Type == 'Healthcare Provider'
# Out:
#   File "<ipython-input-85-60647f637a21>", line 1
#     hprov=df.Covered Entity Type == 'Healthcare Provider'
#                           ^
# SyntaxError: invalid syntax

# %%
df.sum
# Out:
# <bound method DataFrame.sum of                                  Name of Covered Entity State  \
# 0                            Brooke Army Medical Center    TX
# 1             Mid America Kidney Stone Association, LLC    MO
# 2       Alaska Department of Health and Social Services    AK
# 3     Health Services for Children with Special Need...    DC
# 4                                     Mark D. Lurie, MD    CA
# 5                              L. Douglas Carlson, M.D.    CA
# 6                                    David I. Cohen, MD    CA
# 7                               Michele Del Vicario, MD    CA
# 8                                   Joseph F. Lopez, MD    CA
# 9                  City of Hope National Medical Center    CA
# 10              The Children's Hospital of Philadelphia    PA
# 11                              Cogent Healthcare, Inc.    TN
# 12               Democracy Data & Communications, LLC (    VA
# 13                                  Kern Medical Center    CA
# ...

# %%
df.describe()
# Out:
#        Individuals Affected          Day        Month         Year
# count          1.646000e+03  1658.000000  1658.000000  1658.000000
# mean           1.024573e+05    15.951146     6.413752  2013.174910
# std            1.997579e+06     8.706266     3.351304     1.978349
# min            5.000000e+02     1.000000     1.000000  2009.000000
# 25%            9.982500e+02     9.000000     4.000000  2012.000000
# 50%            2.300000e+03    15.000000     6.000000  2013.000000
# 75%            7.599750e+03    23.750000     9.000000  2015.000000
# max            7.880000e+07    31.000000    12.000000  2016.000000

# %%
df.corr()
# Out:
#                       Individuals Affected       Day     Month      Year
# Individuals Affected              1.000000 -0.016467 -0.022435  0.031627
# Day                              -0.016467  1.000000  0.010353 -0.045614
# Month                            -0.022435  0.010353  1.000000 -0.133715
# Year                              0.031627 -0.045614 -0.133715  1.000000

# %%
df.head()
# Out:
#                               Name of Covered Entity State  \
# 0                         Brooke Army Medical Center    TX
# 1          Mid America Kidney Stone Association, LLC    MO
# 2    Alaska Department of Health and Social Services    AK
# 3  Health Services for Children with Special Need...    DC
# 4                                  Mark D. Lurie, MD    CA
#
#    Covered Entity Type  Individuals Affected Breach Submission Date  \
# 0  Healthcare Provider                1000.0               10/21/09
# 1  Healthcare Provider                1000.0               10/28/09
# 2  Healthcare Provider                 501.0               10/30/09
# 3          Health Plan                3800.0               11/17/09
# 4  Healthcare Provider                5166.0               11/20/09
#
#   Type of Breach         Location of Breached Information  \
# 0          Theft                              Paper/Films
# 1          Theft                           Network Server
# ...

# %%
hi=pd.read_csv('HospInfo.csv')

# %%
hi.head()
# Out:
#    Provider ID                   Hospital Name                     Address  \
# 0        10005   MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 1        10012  DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE
# 2        10032                WEDOWEE HOSPITAL       209 NORTH MAIN STREET
# 3        10095            HALE COUNTY HOSPITAL            508 GREEN STREET
# 4        10131        CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE
#
#          City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0        BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 1  FORT PAYNE    AL     35968     DE KALB    2568453150  Acute Care Hospitals
# 2     WEDOWEE    AL     36278    RANDOLPH    2563572111  Acute Care Hospitals
# 3  GREENSBORO    AL     36744        HALE    3346243024  Acute Care Hospitals
# 4  HUNTSVILLE    AL     35801     MADISON    2568823100  Acute Care Hospitals
#
# ...

# %%
hi.corr()
# Out:
#                     Provider ID  ZIP Code  Phone Number  Emergency Services
# Provider ID            1.000000 -0.110463      0.022860            0.044191
# ZIP Code              -0.110463  1.000000      0.021930           -0.041373
# Phone Number           0.022860  0.021930      1.000000            0.015448
# Emergency Services     0.044191 -0.041373      0.015448            1.000000
